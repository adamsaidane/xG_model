# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
from mplsoccer import Pitch, VerticalPitch, FontManager

# %%
df_shot=pd.read_csv('shots_data/shots_openplay_foot.csv')
df_shot=df_shot[df_shot['distance']<=20]
df_shot=df_shot[df_shot['1on1']==1]
df_shot
# Out:
# C:\Users\ADAM\AppData\Local\Temp\ipykernel_17992\1069977551.py:1: DtypeWarning: Columns (9) have mixed types. Specify dtype option on import or set low_memory=False.
#   df_shot=pd.read_csv('shots_openplay_foot.csv')
#        competition_id  season_id  match_id       location shot_outcome  \
# 29773               7         27   3901253  [115.3, 41.0]        Saved
# 29774               9         27   3890367  [115.3, 44.9]        Saved
# 29775              11         41     69207  [101.6, 38.6]        Saved
# 29776               2         27   3754183  [101.4, 43.5]         Post
# 29777               7         27   3900576  [108.9, 30.8]        Off T
# ...               ...        ...       ...            ...          ...
# 32755              11         27   3825695  [114.8, 25.3]         Post
# 32756              11         22     69282  [115.0, 25.2]        Off T
# 32757              37          4     19764  [114.0, 30.0]        Saved
# 32758               2         27   3754093  [115.0, 25.2]        Off T
# 32759             116         68   3750234  [113.8, 55.6]        Off T
#
#        shot_statsbomb_xg under_pressure  shot_type shot_body_part  \
# 29773           0.857377            NaN  Open Play     Right Foot
# 29774           0.521554            NaN  Open Play     Right Foot
# 29775           0.444189            NaN  Open Play     Right Foot
# 29776           0.408810            NaN  Open Play     Right Foot
# 29777           0.466231            NaN  Open Play     Right Foot
# ...                  ...            ...        ...            ...
# 32755           0.018246            NaN  Open Play      Left Foot
# 32756           0.016359            NaN  Open Play      Left Foot
# 32757           0.199656            NaN  Open Play     Right Foot
# 32758           0.015944            NaN  Open Play     Right Foot
# 32759           0.016752           True  Open Play     Right Foot
#
#       shot_one_on_one  ...   x_gk  y_gk      angle   distance  goal  1on1  \
# 29773            True  ...  117.7  38.3  79.321473   4.700000     0     1
# 29774            True  ...  117.9  42.8  51.321613   4.785394     0     1
# 29775            True  ...  108.9  40.0  24.398711  18.400000     0     1
# 29776            True  ...  106.1  42.6  23.500402  18.600000     0     1
# 29777            True  ...  111.2  31.9  24.837607  12.257651     0     1
# ...               ...  ...    ...   ...        ...        ...   ...   ...
# 32755            True  ...  118.2  36.6  10.378973  11.896638     0     1
# 32756            True  ...  119.2  36.3   9.948916  11.901260     0     1
# 32757            True  ...  118.0  38.0  21.801409   8.485281     0     1
# 32758            True  ...  119.1  36.2   9.948916  11.901260     0     1
# 32759            True  ...  118.4  43.3  10.570191  13.152946     0     1
#
#        underPressure  DistanceShooterGk  DistanceGk  minus
# 29773              0           3.612478    2.300000   -2.4
# 29774              0           3.342155    2.100000   -2.6
# 29775              0           7.433034   11.100000   -7.3
# 29776              0           4.785394   13.900000   -4.7
# 29777              0           2.549510    9.708244   -2.3
# ...              ...                ...         ...    ...
# 32755              0          11.800424    1.800000   -3.4
# 32756              0          11.868024    0.800000   -4.2
# 32757              0           8.944272    2.000000   -4.0
# 32758              0          11.739250    0.900000   -4.1
# 32759              1          13.132022    1.600000   -4.6
#
# [2987 rows x 24 columns]

# %%
df_goals=df_shot[df_shot['shot_outcome']=='Goal'].copy()
df_no_goals=df_shot[df_shot['shot_outcome']!='Goal'].copy()

# %%
pitch = VerticalPitch(line_color='black',half=True, pitch_type='custom', pitch_length=120, pitch_width=80, line_zorder = 4,goal_type='box',
    goal_alpha=1)

fig, ax = pitch.draw(figsize=(12, 10))

no_goals=pitch.scatter(
    df_no_goals['x'],df_no_goals['y'],
    c='#ba4f45', 
    marker='o',  
    ax=ax, label="No goal"
)
goals = pitch.scatter(
    df_goals['x'], df_goals['y'],
    c='#ad993c', 
    marker='o',  
    ax=ax, label="Goal" 
)

plt.legend(loc='best')
plt.show()

# %%
pitch = VerticalPitch(line_color='black',half=True, pitch_type='custom', pitch_length=120, pitch_width=80, line_zorder = 4,goal_type='box',
    goal_alpha=1)

fig, ax = pitch.draw(figsize=(12, 10))

pitch.kdeplot(
    x=df_goals['x'],
    y=df_goals['y'],
    ax=ax,
    cmap='Reds',      
    shade=True      
)

fig.suptitle('Goal map' , fontsize = 20)
plt.show()
# Out:
# c:\Users\ADAM\scoop\apps\python\3.12.4\Lib\site-packages\mplsoccer\_pitch_plot.py:167: FutureWarning:
#
# `shade` is now deprecated in favor of `fill`; setting `fill=True`.
# This will become an error in seaborn v0.14.0; please update your code.
#
#   return sns.kdeplot(x=x, y=y, ax=ax, clip=self.kde_clip, **kwargs)

# %%
pitch = VerticalPitch(line_color='black',half=True, pitch_type='custom', pitch_length=120, pitch_width=80, line_zorder = 4,goal_type='box',
    goal_alpha=1)

fig, ax = pitch.draw(figsize=(12, 10))

pitch.kdeplot(df_shot['x'],df_shot['y'],ax=ax,cmap='Reds',shade=True)
fig.suptitle('Shot map' , fontsize = 20)
plt.show()
# Out:
# c:\Users\ADAM\scoop\apps\python\3.12.4\Lib\site-packages\mplsoccer\_pitch_plot.py:167: FutureWarning:
#
# `shade` is now deprecated in favor of `fill`; setting `fill=True`.
# This will become an error in seaborn v0.14.0; please update your code.
#
#   return sns.kdeplot(x=x, y=y, ax=ax, clip=self.kde_clip, **kwargs)

# %%
pitch = VerticalPitch(line_color='black',half=True, pitch_type='custom', pitch_length=120, pitch_width=80, line_zorder = 4,goal_type='box',
    goal_alpha=1)
fig, ax = pitch.grid(grid_height=0.9, title_height=0.06, axis=False,
                     endnote_height=0.04, title_space=0, endnote_space=0)
bin_statistic_shots = pitch.bin_statistic(df_shot["x"], df_shot["y"], bins=100)
shot_grid = pitch.heatmap(bin_statistic_shots, ax=ax["pitch"], cmap='Blues')

fig.suptitle('Shot grid' , fontsize = 20)
plt.show()

# %%
pitch = VerticalPitch(line_color='black',half=True, pitch_type='custom', pitch_length=120, pitch_width=80, line_zorder = 4,goal_type='box',
    goal_alpha=1)
fig, ax = pitch.grid(grid_height=0.9, title_height=0.06, axis=False,
                     endnote_height=0.04, title_space=0, endnote_space=0)
bin_statistic_goals = pitch.bin_statistic(df_goals["x"], df_goals["y"], bins=100)
shot_grid = pitch.heatmap(bin_statistic_goals, ax=ax["pitch"], cmap='Blues')

fig.suptitle('Goal grid' , fontsize = 20)
plt.show()

# %%
pitch = VerticalPitch(line_color='black',half=True, pitch_type='custom', pitch_length=120, pitch_width=80, line_zorder = 4,goal_type='box',
    goal_alpha=1)
fig, ax = pitch.grid(grid_height=0.9, title_height=0.06, axis=False,
                     endnote_height=0.04, title_space=0, endnote_space=0)
bin_statistic = pitch.bin_statistic(df_shot['x'], df_shot['y'], bins = 100)
bin_statistic["statistic"] = bin_statistic_goals["statistic"]/bin_statistic["statistic"]
pcm = pitch.heatmap(bin_statistic, ax=ax["pitch"], cmap='Blues', vmin = 0, vmax = 0.8)
ax_cbar = fig.add_axes((0.95, 0.05, 0.04, 0.8))
cbar = plt.colorbar(pcm, cax=ax_cbar)
fig.suptitle('Goals/Shots' , fontsize = 20)
plt.show()
# Out:
# C:\Users\ADAM\AppData\Local\Temp\ipykernel_17992\1148321986.py:6: RuntimeWarning: invalid value encountered in divide
#   bin_statistic["statistic"] = bin_statistic_goals["statistic"]/bin_statistic["statistic"]

# %%
fig, ax = plt.subplots()
ax.plot(df_shot['angle'], df_shot['goal'], linestyle='none', marker= '.', markersize= 12, color='black')
ax.set_ylabel('Goal scored')
ax.set_xlabel("Shot angle (degrees)")
plt.ylim((-0.05,1.05))
ax.set_yticks([0,1])
ax.set_yticklabels(['No','Yes'])
plt.show()

# %%
shotcount_ang = np.histogram(df_shot['angle'], bins=10, range=[0, 180])
df_goals=df_shot[df_shot['shot_outcome']=='Goal'].copy()
goalcount_ang = np.histogram(df_goals['angle'], bins=10, range=[0, 180])
np.seterr(divide='ignore', invalid='ignore')
prob_goal = np.divide(goalcount_ang[0], shotcount_ang[0])
angle = shotcount_ang[1]
midangle = (angle[:-1] + angle[1:])/2
fig,ax = plt.subplots()
ax.plot(midangle, prob_goal, linestyle='none', marker= '.', markersize= 12, color='black')
ax.set_ylabel('Probability chance scored')
ax.set_xlabel("Shot angle (degrees)")
ax.spines['top'].set_visible(False)
ax.spines['right'].set_visible(False)
plt.show()

# %%
shotcount_dist = np.histogram(df_shot['distance'],bins=70,range=[0, 70])
goalcount_dist = np.histogram(df_goals['distance'],bins=70,range=[0, 70])
prob_goal = np.divide(goalcount_dist[0],shotcount_dist[0])
distance = shotcount_dist[1]
middistance= (distance[:-1] + distance[1:])/2
fig, ax = plt.subplots()
ax.plot(middistance, prob_goal, linestyle='none', marker= '.', color='black')
ax.set_ylabel('Probability chance scored')
ax.set_xlabel("Distance from goal (metres)")
ax.spines['top'].set_visible(False)
ax.spines['right'].set_visible(False)

plt.show()

# %%
shotcount_nbr = np.histogram(df_shot['num_opposing_players'], bins=20, range=[0, 10])
df_goals=df_shot[df_shot['shot_outcome']=='Goal'].copy()
goalcount_nbr = np.histogram(df_goals['num_opposing_players'], bins=20, range=[0, 10])
np.seterr(divide='ignore', invalid='ignore')
prob_goal = np.divide(goalcount_nbr[0], shotcount_nbr[0])
num_opposing_players = shotcount_nbr[1]
midnum_opposing_players = (num_opposing_players[:-1] + num_opposing_players[1:])/2
fig,ax = plt.subplots()
ax.plot(midnum_opposing_players, prob_goal, linestyle='none', marker= '.', markersize= 12, color='black')
ax.set_ylabel('Probability chance scored')
ax.set_xlabel("Number of opposing players")
ax.spines['top'].set_visible(False)
ax.spines['right'].set_visible(False)
plt.show()

# %%
shotcount_underPressure = np.histogram(df_shot['underPressure'], bins=70, range=[0, 2])
df_goals=df_shot[df_shot['shot_outcome']=='Goal'].copy()
goalcount_underPressure = np.histogram(df_goals['underPressure'], bins=70, range=[0, 2])
np.seterr(divide='ignore', invalid='ignore')
prob_goal = np.divide(goalcount_underPressure[0], shotcount_underPressure[0])
underPressure = shotcount_underPressure[1]
midunderPressure = (underPressure[:-1] + underPressure[1:])/2
fig,ax = plt.subplots()
ax.plot(midunderPressure, prob_goal, linestyle='none', marker= '.', markersize= 12, color='black')
ax.set_ylabel('Probability chance scored')
ax.set_xlabel("One on One")
ax.spines['top'].set_visible(False)
ax.spines['right'].set_visible(False)
plt.show()

# %%
shotcount_DistanceShooterGk = np.histogram(df_shot['DistanceShooterGk'], bins=70, range=[0, 40])
df_goals=df_shot[df_shot['shot_outcome']=='Goal'].copy()
goalcount_DistanceShooterGk = np.histogram(df_goals['DistanceShooterGk'], bins=70, range=[0, 40])
np.seterr(divide='ignore', invalid='ignore')
prob_goal = np.divide(goalcount_DistanceShooterGk[0], shotcount_DistanceShooterGk[0])
DistanceShooterGk = shotcount_DistanceShooterGk[1]
midDistanceShooterGk = (DistanceShooterGk[:-1] + DistanceShooterGk[1:])/2
fig,ax = plt.subplots()
ax.plot(midDistanceShooterGk, prob_goal, linestyle='none', marker= '.', markersize= 12, color='black')
ax.set_ylabel('Probability chance scored')
ax.set_xlabel("Distance Shooter Gk")
ax.spines['top'].set_visible(False)
ax.spines['right'].set_visible(False)
plt.show()

# %%
shotcount_DistanceGk = np.histogram(df_shot['DistanceGk'], bins=70, range=[-40, 40])
df_goals=df_shot[df_shot['shot_outcome']=='Goal'].copy()
goalcount_DistanceGk = np.histogram(df_goals['DistanceGk'], bins=70, range=[-40, 40])
np.seterr(divide='ignore', invalid='ignore')
prob_goal = np.divide(goalcount_DistanceGk[0], shotcount_DistanceGk[0])
DistanceGk = shotcount_DistanceGk[1]
midDistanceGk = (DistanceGk[:-1] + DistanceGk[1:])/2
fig,ax = plt.subplots()
ax.plot(midDistanceGk, prob_goal, linestyle='none', marker= '.', markersize= 12, color='black')
ax.set_ylabel('Probability chance scored')
ax.set_xlabel("Distance Gk")
ax.spines['top'].set_visible(False)
ax.spines['right'].set_visible(False)
plt.show()

# %%
x = df_shot[['angle','distance','DistanceShooterGk','DistanceGk','num_opposing_players']]
x.fillna(0, inplace=True)
y = df_shot['goal']

import xgboost as xgb
from sklearn.model_selection import train_test_split

x_train, x_test, y_train, y_test = train_test_split(x, y, test_size=0.1, random_state=42)

dtrain = xgb.DMatrix(x_train, label=y_train)
dtest = xgb.DMatrix(x_test, label=y_test)

params = {
    'objective': 'binary:logistic',
    'eval_metric': 'logloss',
    'eta': 0.01,
    'max_depth': 4,
    'subsample': 0.9,
    'colsample_bytree': 0.8
}

evals = [(dtrain, 'train'), (dtest, 'test')]
bst = xgb.train(params, dtrain, num_boost_round=2500, evals=evals, early_stopping_rounds=250)

y_pred_prob = bst.predict(dtest)
# Out:
# C:\Users\ADAM\AppData\Local\Temp\ipykernel_17992\1993542442.py:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   x.fillna(0, inplace=True)
# [0]	train-logloss:0.55863	test-logloss:0.52248
# [1]	train-logloss:0.55698	test-logloss:0.52158
# [2]	train-logloss:0.55523	test-logloss:0.52064
# [3]	train-logloss:0.55355	test-logloss:0.51977
# [4]	train-logloss:0.55187	test-logloss:0.51875
# [5]	train-logloss:0.55072	test-logloss:0.51816
# [6]	train-logloss:0.54912	test-logloss:0.51741
# [7]	train-logloss:0.54753	test-logloss:0.51652
# [8]	train-logloss:0.54604	test-logloss:0.51571
# [9]	train-logloss:0.54496	test-logloss:0.51519
# [10]	train-logloss:0.54346	test-logloss:0.51457
# [11]	train-logloss:0.54247	test-logloss:0.51407
# [12]	train-logloss:0.54105	test-logloss:0.51336
# [13]	train-logloss:0.53961	test-logloss:0.51260
# [14]	train-logloss:0.53823	test-logloss:0.51183
# [15]	train-logloss:0.53690	test-logloss:0.51109
# [16]	train-logloss:0.53555	test-logloss:0.51038
# [17]	train-logloss:0.53459	test-logloss:0.50993
# [18]	train-logloss:0.53329	test-logloss:0.50924
# [19]	train-logloss:0.53202	test-logloss:0.50857
# [20]	train-logloss:0.53076	test-logloss:0.50798
# [21]	train-logloss:0.52953	test-logloss:0.50736
# [22]	train-logloss:0.52864	test-logloss:0.50694
# [23]	train-logloss:0.52785	test-logloss:0.50653
# [24]	train-logloss:0.52662	test-logloss:0.50600
# [25]	train-logloss:0.52547	test-logloss:0.50548
# [26]	train-logloss:0.52429	test-logloss:0.50496
# [27]	train-logloss:0.52311	test-logloss:0.50470
# [28]	train-logloss:0.52198	test-logloss:0.50414
# [29]	train-logloss:0.52086	test-logloss:0.50347
# [30]	train-logloss:0.51972	test-logloss:0.50289
# [31]	train-logloss:0.51863	test-logloss:0.50252
# [32]	train-logloss:0.51758	test-logloss:0.50204
# [33]	train-logloss:0.51651	test-logloss:0.50152
# [34]	train-logloss:0.51545	test-logloss:0.50115
# [35]	train-logloss:0.51444	test-logloss:0.50067
# [36]	train-logloss:0.51369	test-logloss:0.50037
# [37]	train-logloss:0.51271	test-logloss:0.49991
# [38]	train-logloss:0.51198	test-logloss:0.49970
# [39]	train-logloss:0.51118	test-logloss:0.49938
# [40]	train-logloss:0.51024	test-logloss:0.49898
# [41]	train-logloss:0.50929	test-logloss:0.49860
# [42]	train-logloss:0.50834	test-logloss:0.49808
# [43]	train-logloss:0.50745	test-logloss:0.49783
# [44]	train-logloss:0.50654	test-logloss:0.49739
# [45]	train-logloss:0.50562	test-logloss:0.49703
# [46]	train-logloss:0.50473	test-logloss:0.49676
# [47]	train-logloss:0.50408	test-logloss:0.49652
# [48]	train-logloss:0.50320	test-logloss:0.49615
# [49]	train-logloss:0.50265	test-logloss:0.49592
# [50]	train-logloss:0.50183	test-logloss:0.49567
# [51]	train-logloss:0.50098	test-logloss:0.49533
# [52]	train-logloss:0.50014	test-logloss:0.49484
# [53]	train-logloss:0.49932	test-logloss:0.49449
# [54]	train-logloss:0.49851	test-logloss:0.49411
# [55]	train-logloss:0.49773	test-logloss:0.49369
# [56]	train-logloss:0.49696	test-logloss:0.49336
# [57]	train-logloss:0.49614	test-logloss:0.49299
# [58]	train-logloss:0.49559	test-logloss:0.49278
# [59]	train-logloss:0.49486	test-logloss:0.49243
# [60]	train-logloss:0.49431	test-logloss:0.49218
# [61]	train-logloss:0.49360	test-logloss:0.49184
# [62]	train-logloss:0.49307	test-logloss:0.49165
# [63]	train-logloss:0.49259	test-logloss:0.49148
# [64]	train-logloss:0.49184	test-logloss:0.49119
# [65]	train-logloss:0.49116	test-logloss:0.49092
# [66]	train-logloss:0.49065	test-logloss:0.49079
# [67]	train-logloss:0.48996	test-logloss:0.49053
# [68]	train-logloss:0.48930	test-logloss:0.49030
# [69]	train-logloss:0.48866	test-logloss:0.49014
# [70]	train-logloss:0.48819	test-logloss:0.48991
# [71]	train-logloss:0.48755	test-logloss:0.48969
# [72]	train-logloss:0.48694	test-logloss:0.48947
# [73]	train-logloss:0.48650	test-logloss:0.48932
# [74]	train-logloss:0.48581	test-logloss:0.48912
# [75]	train-logloss:0.48518	test-logloss:0.48878
# [76]	train-logloss:0.48458	test-logloss:0.48857
# [77]	train-logloss:0.48401	test-logloss:0.48843
# [78]	train-logloss:0.48337	test-logloss:0.48827
# [79]	train-logloss:0.48293	test-logloss:0.48816
# [80]	train-logloss:0.48234	test-logloss:0.48803
# [81]	train-logloss:0.48173	test-logloss:0.48781
# [82]	train-logloss:0.48128	test-logloss:0.48776
# [83]	train-logloss:0.48087	test-logloss:0.48761
# [84]	train-logloss:0.48046	test-logloss:0.48755
# [85]	train-logloss:0.48004	test-logloss:0.48740
# [86]	train-logloss:0.47949	test-logloss:0.48724
# [87]	train-logloss:0.47896	test-logloss:0.48702
# [88]	train-logloss:0.47855	test-logloss:0.48691
# [89]	train-logloss:0.47814	test-logloss:0.48681
# [90]	train-logloss:0.47761	test-logloss:0.48663
# [91]	train-logloss:0.47723	test-logloss:0.48656
# [92]	train-logloss:0.47671	test-logloss:0.48637
# [93]	train-logloss:0.47619	test-logloss:0.48623
# [94]	train-logloss:0.47567	test-logloss:0.48610
# [95]	train-logloss:0.47519	test-logloss:0.48595
# [96]	train-logloss:0.47472	test-logloss:0.48585
# [97]	train-logloss:0.47436	test-logloss:0.48577
# [98]	train-logloss:0.47383	test-logloss:0.48563
# [99]	train-logloss:0.47337	test-logloss:0.48544
# [100]	train-logloss:0.47292	test-logloss:0.48536
# [101]	train-logloss:0.47245	test-logloss:0.48526
# [102]	train-logloss:0.47203	test-logloss:0.48526
# [103]	train-logloss:0.47156	test-logloss:0.48514
# [104]	train-logloss:0.47113	test-logloss:0.48503
# [105]	train-logloss:0.47070	test-logloss:0.48496
# [106]	train-logloss:0.47019	test-logloss:0.48484
# [107]	train-logloss:0.46970	test-logloss:0.48466
# [108]	train-logloss:0.46928	test-logloss:0.48458
# [109]	train-logloss:0.46883	test-logloss:0.48459
# [110]	train-logloss:0.46836	test-logloss:0.48456
# [111]	train-logloss:0.46797	test-logloss:0.48438
# [112]	train-logloss:0.46749	test-logloss:0.48433
# [113]	train-logloss:0.46703	test-logloss:0.48429
# [114]	train-logloss:0.46672	test-logloss:0.48426
# [115]	train-logloss:0.46631	test-logloss:0.48410
# [116]	train-logloss:0.46595	test-logloss:0.48402
# [117]	train-logloss:0.46552	test-logloss:0.48391
# [118]	train-logloss:0.46507	test-logloss:0.48390
# [119]	train-logloss:0.46469	test-logloss:0.48380
# [120]	train-logloss:0.46433	test-logloss:0.48372
# [121]	train-logloss:0.46398	test-logloss:0.48365
# [122]	train-logloss:0.46363	test-logloss:0.48360
# [123]	train-logloss:0.46336	test-logloss:0.48357
# [124]	train-logloss:0.46301	test-logloss:0.48348
# [125]	train-logloss:0.46266	test-logloss:0.48343
# [126]	train-logloss:0.46230	test-logloss:0.48337
# [127]	train-logloss:0.46193	test-logloss:0.48328
# [128]	train-logloss:0.46157	test-logloss:0.48328
# [129]	train-logloss:0.46118	test-logloss:0.48322
# [130]	train-logloss:0.46086	test-logloss:0.48324
# [131]	train-logloss:0.46053	test-logloss:0.48321
# [132]	train-logloss:0.46016	test-logloss:0.48319
# [133]	train-logloss:0.45983	test-logloss:0.48316
# [134]	train-logloss:0.45957	test-logloss:0.48314
# [135]	train-logloss:0.45923	test-logloss:0.48314
# [136]	train-logloss:0.45892	test-logloss:0.48313
# [137]	train-logloss:0.45863	test-logloss:0.48305
# [138]	train-logloss:0.45831	test-logloss:0.48316
# [139]	train-logloss:0.45793	test-logloss:0.48315
# [140]	train-logloss:0.45758	test-logloss:0.48315
# [141]	train-logloss:0.45729	test-logloss:0.48315
# [142]	train-logloss:0.45694	test-logloss:0.48315
# [143]	train-logloss:0.45666	test-logloss:0.48318
# [144]	train-logloss:0.45638	test-logloss:0.48315
# [145]	train-logloss:0.45608	test-logloss:0.48313
# [146]	train-logloss:0.45576	test-logloss:0.48301
# [147]	train-logloss:0.45543	test-logloss:0.48296
# [148]	train-logloss:0.45515	test-logloss:0.48295
# [149]	train-logloss:0.45485	test-logloss:0.48283
# [150]	train-logloss:0.45464	test-logloss:0.48281
# [151]	train-logloss:0.45435	test-logloss:0.48275
# [152]	train-logloss:0.45408	test-logloss:0.48275
# [153]	train-logloss:0.45378	test-logloss:0.48270
# [154]	train-logloss:0.45356	test-logloss:0.48269
# [155]	train-logloss:0.45322	test-logloss:0.48267
# [156]	train-logloss:0.45300	test-logloss:0.48269
# [157]	train-logloss:0.45274	test-logloss:0.48276
# [158]	train-logloss:0.45249	test-logloss:0.48282
# [159]	train-logloss:0.45223	test-logloss:0.48281
# [160]	train-logloss:0.45202	test-logloss:0.48280
# [161]	train-logloss:0.45178	test-logloss:0.48280
# [162]	train-logloss:0.45149	test-logloss:0.48279
# [163]	train-logloss:0.45124	test-logloss:0.48281
# [164]	train-logloss:0.45098	test-logloss:0.48276
# [165]	train-logloss:0.45072	test-logloss:0.48263
# [166]	train-logloss:0.45044	test-logloss:0.48259
# [167]	train-logloss:0.45020	test-logloss:0.48257
# [168]	train-logloss:0.44993	test-logloss:0.48248
# [169]	train-logloss:0.44969	test-logloss:0.48250
# [170]	train-logloss:0.44946	test-logloss:0.48251
# [171]	train-logloss:0.44922	test-logloss:0.48253
# [172]	train-logloss:0.44896	test-logloss:0.48256
# [173]	train-logloss:0.44871	test-logloss:0.48263
# [174]	train-logloss:0.44850	test-logloss:0.48275
# [175]	train-logloss:0.44832	test-logloss:0.48278
# [176]	train-logloss:0.44812	test-logloss:0.48281
# [177]	train-logloss:0.44793	test-logloss:0.48276
# [178]	train-logloss:0.44767	test-logloss:0.48286
# [179]	train-logloss:0.44742	test-logloss:0.48279
# [180]	train-logloss:0.44721	test-logloss:0.48284
# [181]	train-logloss:0.44697	test-logloss:0.48287
# [182]	train-logloss:0.44673	test-logloss:0.48288
# [183]	train-logloss:0.44657	test-logloss:0.48291
# [184]	train-logloss:0.44634	test-logloss:0.48298
# [185]	train-logloss:0.44620	test-logloss:0.48300
# [186]	train-logloss:0.44602	test-logloss:0.48310
# [187]	train-logloss:0.44579	test-logloss:0.48305
# [188]	train-logloss:0.44559	test-logloss:0.48313
# [189]	train-logloss:0.44535	test-logloss:0.48316
# [190]	train-logloss:0.44512	test-logloss:0.48309
# [191]	train-logloss:0.44496	test-logloss:0.48312
# [192]	train-logloss:0.44476	test-logloss:0.48315
# [193]	train-logloss:0.44452	test-logloss:0.48324
# [194]	train-logloss:0.44431	test-logloss:0.48322
# [195]	train-logloss:0.44417	test-logloss:0.48320
# [196]	train-logloss:0.44397	test-logloss:0.48331
# [197]	train-logloss:0.44373	test-logloss:0.48339
# [198]	train-logloss:0.44356	test-logloss:0.48339
# [199]	train-logloss:0.44335	test-logloss:0.48342
# [200]	train-logloss:0.44318	test-logloss:0.48346
# [201]	train-logloss:0.44299	test-logloss:0.48352
# [202]	train-logloss:0.44280	test-logloss:0.48345
# [203]	train-logloss:0.44263	test-logloss:0.48341
# [204]	train-logloss:0.44241	test-logloss:0.48341
# [205]	train-logloss:0.44223	test-logloss:0.48344
# [206]	train-logloss:0.44203	test-logloss:0.48355
# [207]	train-logloss:0.44190	test-logloss:0.48360
# [208]	train-logloss:0.44172	test-logloss:0.48363
# [209]	train-logloss:0.44160	test-logloss:0.48363
# [210]	train-logloss:0.44142	test-logloss:0.48370
# [211]	train-logloss:0.44120	test-logloss:0.48372
# [212]	train-logloss:0.44104	test-logloss:0.48377
# [213]	train-logloss:0.44084	test-logloss:0.48379
# [214]	train-logloss:0.44067	test-logloss:0.48387
# [215]	train-logloss:0.44051	test-logloss:0.48401
# [216]	train-logloss:0.44036	test-logloss:0.48412
# [217]	train-logloss:0.44019	test-logloss:0.48418
# [218]	train-logloss:0.44002	test-logloss:0.48425
# [219]	train-logloss:0.43983	test-logloss:0.48434
# [220]	train-logloss:0.43967	test-logloss:0.48444
# [221]	train-logloss:0.43950	test-logloss:0.48445
# [222]	train-logloss:0.43934	test-logloss:0.48453
# [223]	train-logloss:0.43919	test-logloss:0.48460
# [224]	train-logloss:0.43898	test-logloss:0.48457
# [225]	train-logloss:0.43881	test-logloss:0.48471
# [226]	train-logloss:0.43863	test-logloss:0.48474
# [227]	train-logloss:0.43843	test-logloss:0.48477
# [228]	train-logloss:0.43823	test-logloss:0.48474
# [229]	train-logloss:0.43807	test-logloss:0.48477
# [230]	train-logloss:0.43793	test-logloss:0.48480
# [231]	train-logloss:0.43779	test-logloss:0.48488
# [232]	train-logloss:0.43762	test-logloss:0.48492
# [233]	train-logloss:0.43748	test-logloss:0.48497
# [234]	train-logloss:0.43735	test-logloss:0.48503
# [235]	train-logloss:0.43720	test-logloss:0.48506
# [236]	train-logloss:0.43706	test-logloss:0.48512
# [237]	train-logloss:0.43693	test-logloss:0.48515
# [238]	train-logloss:0.43678	test-logloss:0.48516
# [239]	train-logloss:0.43664	test-logloss:0.48522
# [240]	train-logloss:0.43647	test-logloss:0.48522
# [241]	train-logloss:0.43632	test-logloss:0.48528
# [242]	train-logloss:0.43621	test-logloss:0.48534
# [243]	train-logloss:0.43609	test-logloss:0.48535
# [244]	train-logloss:0.43593	test-logloss:0.48536
# [245]	train-logloss:0.43577	test-logloss:0.48538
# [246]	train-logloss:0.43560	test-logloss:0.48543
# [247]	train-logloss:0.43542	test-logloss:0.48544
# [248]	train-logloss:0.43528	test-logloss:0.48554
# [249]	train-logloss:0.43515	test-logloss:0.48557
# [250]	train-logloss:0.43501	test-logloss:0.48563
# [251]	train-logloss:0.43488	test-logloss:0.48573
# [252]	train-logloss:0.43472	test-logloss:0.48590
# [253]	train-logloss:0.43458	test-logloss:0.48594
# [254]	train-logloss:0.43447	test-logloss:0.48604
# [255]	train-logloss:0.43435	test-logloss:0.48607
# [256]	train-logloss:0.43423	test-logloss:0.48613
# [257]	train-logloss:0.43409	test-logloss:0.48618
# [258]	train-logloss:0.43396	test-logloss:0.48613
# [259]	train-logloss:0.43384	test-logloss:0.48618
# [260]	train-logloss:0.43369	test-logloss:0.48632
# [261]	train-logloss:0.43357	test-logloss:0.48636
# [262]	train-logloss:0.43344	test-logloss:0.48636
# [263]	train-logloss:0.43330	test-logloss:0.48636
# [264]	train-logloss:0.43321	test-logloss:0.48631
# [265]	train-logloss:0.43309	test-logloss:0.48637
# [266]	train-logloss:0.43291	test-logloss:0.48639
# [267]	train-logloss:0.43278	test-logloss:0.48643
# [268]	train-logloss:0.43263	test-logloss:0.48640
# [269]	train-logloss:0.43248	test-logloss:0.48650
# [270]	train-logloss:0.43236	test-logloss:0.48657
# [271]	train-logloss:0.43227	test-logloss:0.48664
# [272]	train-logloss:0.43217	test-logloss:0.48671
# [273]	train-logloss:0.43205	test-logloss:0.48675
# [274]	train-logloss:0.43192	test-logloss:0.48682
# [275]	train-logloss:0.43183	test-logloss:0.48687
# [276]	train-logloss:0.43167	test-logloss:0.48694
# [277]	train-logloss:0.43157	test-logloss:0.48697
# [278]	train-logloss:0.43146	test-logloss:0.48701
# [279]	train-logloss:0.43135	test-logloss:0.48707
# [280]	train-logloss:0.43122	test-logloss:0.48712
# [281]	train-logloss:0.43108	test-logloss:0.48722
# [282]	train-logloss:0.43098	test-logloss:0.48723
# [283]	train-logloss:0.43084	test-logloss:0.48720
# [284]	train-logloss:0.43073	test-logloss:0.48729
# [285]	train-logloss:0.43059	test-logloss:0.48732
# [286]	train-logloss:0.43046	test-logloss:0.48729
# [287]	train-logloss:0.43036	test-logloss:0.48734
# [288]	train-logloss:0.43021	test-logloss:0.48737
# [289]	train-logloss:0.43012	test-logloss:0.48741
# [290]	train-logloss:0.42999	test-logloss:0.48740
# [291]	train-logloss:0.42986	test-logloss:0.48742
# [292]	train-logloss:0.42974	test-logloss:0.48745
# [293]	train-logloss:0.42959	test-logloss:0.48759
# [294]	train-logloss:0.42946	test-logloss:0.48768
# [295]	train-logloss:0.42935	test-logloss:0.48778
# [296]	train-logloss:0.42927	test-logloss:0.48788
# [297]	train-logloss:0.42915	test-logloss:0.48787
# [298]	train-logloss:0.42901	test-logloss:0.48793
# [299]	train-logloss:0.42885	test-logloss:0.48799
# [300]	train-logloss:0.42874	test-logloss:0.48804
# [301]	train-logloss:0.42859	test-logloss:0.48807
# [302]	train-logloss:0.42849	test-logloss:0.48815
# [303]	train-logloss:0.42836	test-logloss:0.48825
# [304]	train-logloss:0.42823	test-logloss:0.48831
# [305]	train-logloss:0.42809	test-logloss:0.48833
# [306]	train-logloss:0.42796	test-logloss:0.48836
# [307]	train-logloss:0.42785	test-logloss:0.48840
# [308]	train-logloss:0.42776	test-logloss:0.48851
# [309]	train-logloss:0.42763	test-logloss:0.48854
# [310]	train-logloss:0.42753	test-logloss:0.48863
# [311]	train-logloss:0.42741	test-logloss:0.48873
# [312]	train-logloss:0.42731	test-logloss:0.48878
# [313]	train-logloss:0.42720	test-logloss:0.48883
# [314]	train-logloss:0.42706	test-logloss:0.48898
# [315]	train-logloss:0.42697	test-logloss:0.48901
# [316]	train-logloss:0.42686	test-logloss:0.48900
# [317]	train-logloss:0.42670	test-logloss:0.48906
# [318]	train-logloss:0.42665	test-logloss:0.48911
# [319]	train-logloss:0.42648	test-logloss:0.48917
# [320]	train-logloss:0.42634	test-logloss:0.48929
# [321]	train-logloss:0.42623	test-logloss:0.48923
# [322]	train-logloss:0.42614	test-logloss:0.48929
# [323]	train-logloss:0.42604	test-logloss:0.48929
# [324]	train-logloss:0.42593	test-logloss:0.48940
# [325]	train-logloss:0.42585	test-logloss:0.48953
# [326]	train-logloss:0.42576	test-logloss:0.48959
# [327]	train-logloss:0.42563	test-logloss:0.48966
# [328]	train-logloss:0.42557	test-logloss:0.48970
# [329]	train-logloss:0.42546	test-logloss:0.48974
# [330]	train-logloss:0.42535	test-logloss:0.48978
# [331]	train-logloss:0.42524	test-logloss:0.48984
# [332]	train-logloss:0.42518	test-logloss:0.48986
# [333]	train-logloss:0.42511	test-logloss:0.48995
# [334]	train-logloss:0.42497	test-logloss:0.49014
# [335]	train-logloss:0.42486	test-logloss:0.49023
# [336]	train-logloss:0.42470	test-logloss:0.49035
# [337]	train-logloss:0.42459	test-logloss:0.49040
# [338]	train-logloss:0.42448	test-logloss:0.49039
# [339]	train-logloss:0.42437	test-logloss:0.49043
# [340]	train-logloss:0.42425	test-logloss:0.49039
# [341]	train-logloss:0.42412	test-logloss:0.49045
# [342]	train-logloss:0.42402	test-logloss:0.49051
# [343]	train-logloss:0.42392	test-logloss:0.49053
# [344]	train-logloss:0.42384	test-logloss:0.49060
# [345]	train-logloss:0.42372	test-logloss:0.49058
# [346]	train-logloss:0.42357	test-logloss:0.49057
# [347]	train-logloss:0.42347	test-logloss:0.49065
# [348]	train-logloss:0.42340	test-logloss:0.49072
# [349]	train-logloss:0.42327	test-logloss:0.49059
# [350]	train-logloss:0.42316	test-logloss:0.49060
# [351]	train-logloss:0.42306	test-logloss:0.49063
# [352]	train-logloss:0.42300	test-logloss:0.49063
# [353]	train-logloss:0.42291	test-logloss:0.49070
# [354]	train-logloss:0.42278	test-logloss:0.49074
# [355]	train-logloss:0.42272	test-logloss:0.49075
# [356]	train-logloss:0.42262	test-logloss:0.49082
# [357]	train-logloss:0.42257	test-logloss:0.49082
# [358]	train-logloss:0.42240	test-logloss:0.49073
# [359]	train-logloss:0.42229	test-logloss:0.49081
# [360]	train-logloss:0.42215	test-logloss:0.49086
# [361]	train-logloss:0.42203	test-logloss:0.49100
# [362]	train-logloss:0.42189	test-logloss:0.49096
# [363]	train-logloss:0.42178	test-logloss:0.49109
# [364]	train-logloss:0.42167	test-logloss:0.49111
# [365]	train-logloss:0.42156	test-logloss:0.49120
# [366]	train-logloss:0.42146	test-logloss:0.49132
# [367]	train-logloss:0.42131	test-logloss:0.49148
# [368]	train-logloss:0.42120	test-logloss:0.49161
# [369]	train-logloss:0.42112	test-logloss:0.49164
# [370]	train-logloss:0.42101	test-logloss:0.49166
# [371]	train-logloss:0.42093	test-logloss:0.49162
# [372]	train-logloss:0.42082	test-logloss:0.49165
# [373]	train-logloss:0.42072	test-logloss:0.49166
# [374]	train-logloss:0.42067	test-logloss:0.49174
# [375]	train-logloss:0.42056	test-logloss:0.49181
# [376]	train-logloss:0.42051	test-logloss:0.49190
# [377]	train-logloss:0.42041	test-logloss:0.49207
# [378]	train-logloss:0.42034	test-logloss:0.49211
# [379]	train-logloss:0.42019	test-logloss:0.49214
# [380]	train-logloss:0.42009	test-logloss:0.49222
# [381]	train-logloss:0.41998	test-logloss:0.49240
# [382]	train-logloss:0.41985	test-logloss:0.49253
# [383]	train-logloss:0.41974	test-logloss:0.49247
# [384]	train-logloss:0.41966	test-logloss:0.49249
# [385]	train-logloss:0.41959	test-logloss:0.49255
# [386]	train-logloss:0.41946	test-logloss:0.49264
# [387]	train-logloss:0.41938	test-logloss:0.49266
# [388]	train-logloss:0.41932	test-logloss:0.49272
# [389]	train-logloss:0.41920	test-logloss:0.49278
# [390]	train-logloss:0.41909	test-logloss:0.49272
# [391]	train-logloss:0.41897	test-logloss:0.49270
# [392]	train-logloss:0.41889	test-logloss:0.49278
# [393]	train-logloss:0.41874	test-logloss:0.49294
# [394]	train-logloss:0.41864	test-logloss:0.49301
# [395]	train-logloss:0.41858	test-logloss:0.49304
# [396]	train-logloss:0.41852	test-logloss:0.49309
# [397]	train-logloss:0.41844	test-logloss:0.49313
# [398]	train-logloss:0.41833	test-logloss:0.49313
# [399]	train-logloss:0.41823	test-logloss:0.49311
# [400]	train-logloss:0.41816	test-logloss:0.49322
# [401]	train-logloss:0.41809	test-logloss:0.49334
# [402]	train-logloss:0.41803	test-logloss:0.49334
# [403]	train-logloss:0.41795	test-logloss:0.49337
# [404]	train-logloss:0.41783	test-logloss:0.49342
# [405]	train-logloss:0.41772	test-logloss:0.49345
# [406]	train-logloss:0.41757	test-logloss:0.49341
# [407]	train-logloss:0.41744	test-logloss:0.49338
# [408]	train-logloss:0.41731	test-logloss:0.49350
# [409]	train-logloss:0.41722	test-logloss:0.49347
# [410]	train-logloss:0.41715	test-logloss:0.49354
# [411]	train-logloss:0.41703	test-logloss:0.49373
# [412]	train-logloss:0.41690	test-logloss:0.49382
# [413]	train-logloss:0.41680	test-logloss:0.49392
# [414]	train-logloss:0.41667	test-logloss:0.49405
# [415]	train-logloss:0.41652	test-logloss:0.49417
# [416]	train-logloss:0.41636	test-logloss:0.49428
# [417]	train-logloss:0.41632	test-logloss:0.49429
# [418]	train-logloss:0.41619	test-logloss:0.49446

# %%
from sklearn.metrics import accuracy_score, roc_auc_score, confusion_matrix, classification_report

y_pred_binary = (y_pred_prob >= 0.5).astype(int)

accuracy = accuracy_score(y_test, y_pred_binary)
print(f"Accuracy: {accuracy:.2f}")

roc_auc = roc_auc_score(y_test, y_pred_prob)
print(f"ROC-AUC Score: {roc_auc:.2f}")

cm = confusion_matrix(y_test, y_pred_binary)
print("Confusion Matrix:")
print(cm)

print("Classification Report:")
print(classification_report(y_test, y_pred_binary))
# Out:
# Accuracy: 0.79
# ROC-AUC Score: 0.69
# Confusion Matrix:
# [[226  10]
#  [ 54   9]]
# Classification Report:
#               precision    recall  f1-score   support
#
#            0       0.81      0.96      0.88       236
#            1       0.47      0.14      0.22        63
#
#     accuracy                           0.79       299
#    macro avg       0.64      0.55      0.55       299
# weighted avg       0.74      0.79      0.74       299

# %%
import matplotlib.pyplot as plt

sorted_indices = np.argsort(x_test['distance'])
sorted_distances = x_test['distance'].iloc[sorted_indices]
sorted_probabilities = y_pred_prob[sorted_indices]

plt.plot(sorted_distances, sorted_probabilities, label="Probability of Goal")
plt.xlabel("Distance")
plt.ylabel("Probability")
plt.title("Goal Probability vs. Distance")
plt.legend()
plt.show()

# %%
sorted_indices = np.argsort(x_test['angle'])
sorted_distances = x_test['angle'].iloc[sorted_indices]
sorted_probabilities = y_pred_prob[sorted_indices]

plt.plot(sorted_distances, sorted_probabilities, label="Probability of Goal")
plt.xlabel("angle")
plt.ylabel("Probability")
plt.title("Goal Probability vs. angle")
plt.legend()
plt.show()

# %%
sorted_indices = np.argsort(x_test['DistanceShooterGk'])
sorted_distances = x_test['DistanceShooterGk'].iloc[sorted_indices]
sorted_probabilities = y_pred_prob[sorted_indices]

plt.plot(sorted_distances, sorted_probabilities, label="Probability of Goal")
plt.xlabel("'DistanceShooterGk'")
plt.ylabel("Probability")
plt.title("Goal Probability vs. 'DistanceShooterGk'")
plt.legend()
plt.show()

# %%
sorted_indices = np.argsort(x_test['DistanceGk'])
sorted_distances = x_test['DistanceGk'].iloc[sorted_indices]
sorted_probabilities = y_pred_prob[sorted_indices]

plt.plot(sorted_distances, sorted_probabilities, label="Probability of Goal")
plt.xlabel("'DistanceGk'")
plt.ylabel("Probability")
plt.title("Goal Probability vs. 'DistanceGk'")
plt.legend()
plt.show()

# %%
xgb.plot_importance(bst, importance_type='weight', title='Feature Importance', xlabel='F score', ylabel='Features')
plt.show()

# %%
bst.save_model('xG_foot_openplay_inside_1on1.json')
